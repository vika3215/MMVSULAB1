# %% [markdown]
# <a href="https://colab.research.google.com/github/vika3215/MMVSULAB1/blob/main/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа №2
# Красноярск

# %% [markdown]
# Номер 1.

# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy.integrate import odeint

data={'year':[1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
'population':[3163370, 3164219, 3160594,	3139464, 3113809,	3099424, 3085791,	3067863, 3048716,	3022092,	3000891,	2981746,	2961871,	2931905, 2901930,	2869315,	2845425,	2837013,	2832591,	2832854,	2829105,	2838396,	2846475,	2852810,	2858773,	2866490,	2875301,	2876497,	2874026,]}
df=pd.DataFrame(data)

plt.plot(df['year'], df['population'])
plt.xlabel('year')
plt.ylabel('population')
plt.title('Population of Krasnoyarsk Krai since 1991')

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
url='https://raw.githubusercontent.com/vika3215/MMVSULAB1/main/Krasnoyarsk.csv'
df=pd.read_csv(url)
print(df)
years=np.array(df['Years'])
population=np.array(df['Population'])

plt.plot(df['Years'], df['Population'])
plt.xlabel('year')
plt.ylabel('population')
plt.title('Population of Krasnoyarsk since 1991')

plt.show()
# Out:
#     Years  Population
# 0    1856        6400
# 1    1923       59258
# 2    1931       82811
# 3    1962      465000
# 4    1970      648113
# 5    1975      758000
# 6    1986      877000
# 7    1991      924000
# 8    1992      925000
# 9    1993      919000
# 10   1994      914000
# 11   1995      869000
# 12   1996      871000
# 13   2000      875500
# 14   2001      875700
# 15   2004      912800
# 16   2005      917200
# 17   2006      920900
# 18   2007      927200
# 19   2008      936400
# 20   2009      947801
# 21   2010      973826
# 22   2011      973900
# 23   2012      997316
# 24   2013     1016385
# 25   2014     1035528
# 26   2015     1052218
# 27   2016     1066934
# 28   2017     1082933
# 29   2018     1090811
# 30   2019     1095286
# 31   2020     1093771
